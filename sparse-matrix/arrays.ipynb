# %%
import numpy as np

# %%
arr = []

# %%
arr
# Out:
# []

# %%
arr.append(5)

# %%
arr
# Out:
# [5]

# %%
len(arr)
# Out:
# 1

# %%
arr2d = np.array([[1,2], [3,4]])
arr2d
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2d[1,1]
# Out:
# 4

# %%
arr
# Out:
# [5]

# %%
np.array(arr)
# Out:
# array([5])

# %%
arr[0]
# Out:
# 5

# %%
v = np.array([[1, 4, 0, 0, 1],
 [0, 0, 0, 0, 0],
 [0, 5, 6, 0, 0],
 [0, 0, 3, 0, 0]])

# %%
v[v[0]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/4w/25gvjsp55xl0mfn87r78hjhc0000gn/T/ipykernel_10648/688868653.py in <module>
# ----> 1 v[v[0]]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
for i in v:
    print(i)
# Out:
# [1 4 0 0 1]
# [0 0 0 0 0]
# [0 5 6 0 0]
# [0 0 3 0 0]

# %%
# for(int i=0; i < v.length; i++)
for i in range(len(v)):
    for j in range(len(v[i])):
        print(str(i) + "," + str(j))
# Out:
# 0,0
# 0,1
# 0,2
# 0,3
# 0,4
# 1,0
# 1,1
# 1,2
# 1,3
# 1,4
# 2,0
# 2,1
# 2,2
# 2,3
# 2,4
# 3,0
# 3,1
# 3,2
# 3,3
# 3,4

# %%
for i in v:
    for j in v[i]:
        print(j)
# Out:
# 1
# 4
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 5
# 6
# 0
# 0
# 0
# 0
# 3
# 0
# 0
